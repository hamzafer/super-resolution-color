# %%
import os
import shutil
from PIL import Image

# Paths to your directories
low_res_src = "dataset/DIV/DIV2K_valid_LR_x8"
high_res_src = "dataset/DIV/X2"
low_res_dest = "dataset/DIV/final/low"
high_res_dest = "dataset/DIV/final/high"
log_file_path = "image_processing.log"  # Log file path

# Ensure destination directories exist
os.makedirs(low_res_dest, exist_ok=True)
os.makedirs(high_res_dest, exist_ok=True)

# Desired dimensions
low_res_dimensions = (255, 169)
high_res_dimensions = (1020, 678)

# Clear or create the log file
with open(log_file_path, "w") as log_file:
    log_file.write("Image Processing Log\n")
    log_file.write("====================\n\n")

# Helper function to process files
def process_images(src_dir, dest_dir, dimensions):
    with open(log_file_path, "a") as log_file:
        for file_name in os.listdir(src_dir):
            src_path = os.path.join(src_dir, file_name)

            # Check if it's a valid file
            if not os.path.isfile(src_path):
                continue

            try:
                # Open the image and check dimensions
                with Image.open(src_path) as img:
                    if img.size == dimensions:
                        # Clean up the file name by removing 'x8', 'x2', etc.
                        new_name = file_name.split('x')[0] + ".png"
                        dest_path = os.path.join(dest_dir, new_name)

                        # Copy the file to the destination
                        shutil.copy2(src_path, dest_path)
                        message = f"Copied: {src_path} -> {dest_path}\n"
                        print(message, end="")
                        log_file.write(message)
                    else:
                        message = f"Skipped (dimensions mismatch): {src_path} ({img.size})\n"
                        print(message, end="")
                        log_file.write(message)
            except Exception as e:
                message = f"Error processing file {src_path}: {e}\n"
                print(message, end="")
                log_file.write(message)

# Process low-res images
print("Processing low-res images...")
with open(log_file_path, "a") as log_file:
    log_file.write("Processing low-res images...\n")
process_images(low_res_src, low_res_dest, low_res_dimensions)

# Process high-res images
print("Processing high-res images...")
with open(log_file_path, "a") as log_file:
    log_file.write("Processing high-res images...\n")
process_images(high_res_src, high_res_dest, high_res_dimensions)

print("Image processing completed.")
with open(log_file_path, "a") as log_file:
    log_file.write("Image processing completed.\n")
# Out:
# Processing low-res images...
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0809x8.png -> dataset/DIV/final/low/0809.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0871x8.png -> dataset/DIV/final/low/0871.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0853x8.png -> dataset/DIV/final/low/0853.png
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0879x8.png ((255, 234))
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0897x8.png ((255, 171))
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0876x8.png -> dataset/DIV/final/low/0876.png
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0817x8.png ((255, 192))
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0824x8.png -> dataset/DIV/final/low/0824.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0842x8.png -> dataset/DIV/final/low/0842.png
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0892x8.png ((255, 160))
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0887x8.png -> dataset/DIV/final/low/0887.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0838x8.png -> dataset/DIV/final/low/0838.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0829x8.png -> dataset/DIV/final/low/0829.png
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0826x8.png ((255, 192))
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0893x8.png -> dataset/DIV/final/low/0893.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0899x8.png -> dataset/DIV/final/low/0899.png
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0869x8.png ((169, 255))
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0864x8.png -> dataset/DIV/final/low/0864.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0843x8.png -> dataset/DIV/final/low/0843.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0801x8.png -> dataset/DIV/final/low/0801.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0858x8.png -> dataset/DIV/final/low/0858.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0806x8.png -> dataset/DIV/final/low/0806.png
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0805x8.png ((255, 192))
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0827x8.png ((255, 192))
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0807x8.png ((255, 141))
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0854x8.png ((255, 133))
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0868x8.png -> dataset/DIV/final/low/0868.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0874x8.png -> dataset/DIV/final/low/0874.png
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0808x8.png -> dataset/DIV/final/low/0808.png
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0865x8.png ((255, 192))
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0900x8.png ((255, 144))
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/0818x8.png ((255, 192))
# Copied: dataset/DIV/DIV2K_valid_LR_x8/0825x8.png -> dataset/DIV/final/low/0825.png
# Skipped (dimensions mismatch): dataset/DIV/DIV2K_valid_LR_x8/
png
# Skipped (dimensions mismatch): dataset/DIV/X2/0833x2.png ((1020, 774))
# Copied: dataset/DIV/X2/0887x2.png -> dataset/DIV/final/high/0887.png
# Copied: dataset/DIV/X2/0811x2.png -> dataset/DIV/final/high/0811.png
# Copied: dataset/DIV/X2/0868x2.png -> dataset/DIV/final/high/0868.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0880x2.png ((678, 1020))
# Skipped (dimensions mismatch): dataset/DIV/X2/0865x2.png ((1020, 768))
# Skipped (dimensions mismatch): dataset/DIV/X2/0835x2.png ((810, 1020))
# Copied: dataset/DIV/X2/0874x2.png -> dataset/DIV/final/high/0874.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0863x2.png ((750, 1020))
# Copied: dataset/DIV/X2/0828x2.png -> dataset/DIV/final/high/0828.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0852x2.png ((1020, 576))
# Copied: dataset/DIV/X2/0858x2.png -> dataset/DIV/final/high/0858.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0848x2.png ((1020, 768))
# Skipped (dimensions mismatch): dataset/DIV/X2/0804x2.png ((1020, 600))
# Copied: dataset/DIV/X2/0840x2.png -> dataset/DIV/final/high/0840.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0818x2.png ((1020, 768))
# Skipped (dimensions mismatch): dataset/DIV/X2/0892x2.png ((1020, 642))
# Skipped (dimensions mismatch): dataset/DIV/X2/0807x2.png ((1020, 564))
# Copied: dataset/DIV/X2/0801x2.png -> dataset/DIV/final/high/0801.png
# Copied: dataset/DIV/X2/0885x2.png -> dataset/DIV/final/high/0885.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0851x2.png ((1020, 672))
# Skipped (dimensions mismatch): dataset/DIV/X2/0867x2.png ((678, 1020))
# Skipped (dimensions mismatch): dataset/DIV/X2/0810x2.png ((1020, 768))
# Copied: dataset/DIV/X2/0861x2.png -> dataset/DIV/final/high/0861.png
# Copied: dataset/DIV/X2/0845x2.png -> dataset/DIV/final/high/0845.png
# Copied: dataset/DIV/X2/0853x2.png -> dataset/DIV/final/high/0853.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0866x2.png ((678, 1020))
# Copied: dataset/DIV/X2/0871x2.png -> dataset/DIV/final/high/0871.png
# Copied: dataset/DIV/X2/0808x2.png -> dataset/DIV/final/high/0808.png
# Copied: dataset/DIV/X2/0814x2.png -> dataset/DIV/final/high/0814.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0813x2.png ((1020, 732))
# Copied: dataset/DIV/X2/0820x2.png -> dataset/DIV/final/high/0820.png
# Copied: dataset/DIV/X2/0834x2.png -> dataset/DIV/final/high/0834.png
# Copied: dataset/DIV/X2/0802x2.png -> dataset/DIV/final/high/0802.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0870x2.png ((1020, 786))
# Copied: dataset/DIV/X2/0829x2.png -> dataset/DIV/final/high/0829.png
# Copied: dataset/DIV/X2/0821x2.png -> dataset/DIV/final/high/0821.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0883x2.png ((1020, 690))
# Skipped (dimensions mismatch): dataset/DIV/X2/0817x2.png ((1020, 768))
# Skipped (dimensions mismatch): dataset/DIV/X2/0875x2.png ((1020, 768))
# Skipped (dimensions mismatch): dataset/DIV/X2/0860x2.png ((1020, 768))
# Skipped (dimensions mismatch): dataset/DIV/X2/0855x2.png ((1020, 1020))
# Copied: dataset/DIV/X2/0806x2.png -> dataset/DIV/final/high/0806.png
# Copied: dataset/DIV/X2/0837x2.png -> dataset/DIV/final/high/0837.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0897x2.png ((1020, 684))
# Copied: dataset/DIV/X2/0842x2.png -> dataset/DIV/final/high/0842.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0823x2.png ((1020, 642))
# Skipped (dimensions mismatch): dataset/DIV/X2/0857x2.png ((1020, 708))
# Skipped (dimensions mismatch): dataset/DIV/X2/0900x2.png ((1020, 576))
# Skipped (dimensions mismatch): dataset/DIV/X2/0812x2.png ((1020, 768))
# Copied: dataset/DIV/X2/0884x2.png -> dataset/DIV/final/high/0884.png
# Copied: dataset/DIV/X2/0843x2.png -> dataset/DIV/final/high/0843.png
# Copied: dataset/DIV/X2/0838x2.png -> dataset/DIV/final/high/0838.png
# Copied: dataset/DIV/X2/0831x2.png -> dataset/DIV/final/high/0831.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0826x2.png ((1020, 768))
# Skipped (dimensions mismatch): dataset/DIV/X2/0877x2.png ((1020, 576))
# Skipped (dimensions mismatch): dataset/DIV/X2/0895x2.png ((1020, 642))
# Skipped (dimensions mismatch): dataset/DIV/X2/0844x2.png ((678, 1020))
# Skipped (dimensions mismatch): dataset/DIV/X2/0869x2.png ((678, 1020))
# Skipped (dimensions mismatch): dataset/DIV/X2/0846x2.png ((1020, 684))
# Copied: dataset/DIV/X2/0859x2.png -> dataset/DIV/final/high/0859.png
# Copied: dataset/DIV/X2/0824x2.png -> dataset/DIV/final/high/0824.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0805x2.png ((1020, 768))
# Copied: dataset/DIV/X2/0832x2.png -> dataset/DIV/final/high/0832.png
# Copied: dataset/DIV/X2/0816x2.png -> dataset/DIV/final/high/0816.png
# Copied: dataset/DIV/X2/0841x2.png -> dataset/DIV/final/high/0841.png
# Copied: dataset/DIV/X2/0809x2.png -> dataset/DIV/final/high/0809.png
# Copied: dataset/DIV/X2/0889x2.png -> dataset/DIV/final/high/0889.png
# Copied: dataset/DIV/X2/0839x2.png -> dataset/DIV/final/high/0839.png
# Copied: dataset/DIV/X2/0825x2.png -> dataset/DIV/final/high/0825.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0890x2.png ((1020, 684))
# Copied: dataset/DIV/X2/0815x2.png -> dataset/DIV/final/high/0815.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0881x2.png ((1020, 630))
# Skipped (dimensions mismatch): dataset/DIV/X2/0827x2.png ((1020, 768))
# Copied: dataset/DIV/X2/0876x2.png -> dataset/DIV/final/high/0876.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0847x2.png ((678, 1020))
# Skipped (dimensions mismatch): dataset/DIV/X2/0822x2.png ((1020, 798))
# Copied: dataset/DIV/X2/0864x2.png -> dataset/DIV/final/high/0864.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0830x2.png ((1020, 408))
# Copied: dataset/DIV/X2/0862x2.png -> dataset/DIV/final/high/0862.png
# Copied: dataset/DIV/X2/0888x2.png -> dataset/DIV/final/high/0888.png
# Copied: dataset/DIV/X2/0856x2.png -> dataset/DIV/final/high/0856.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0836x2.png ((1020, 768))
# Copied: dataset/DIV/X2/0850x2.png -> dataset/DIV/final/high/0850.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0854x2.png ((1020, 534))
# Copied: dataset/DIV/X2/0893x2.png -> dataset/DIV/final/high/0893.png
# Skipped (dimensions mismatch): dataset/DIV/X2/0894x2.png ((678, 1020))
# Skipped (dimensions mismatch): dataset/DIV/X2/0879x2.png ((1020, 936))
# Copied: dataset/DIV/X2/0886x2.png -> dataset/DIV/final/high/0886.png
# Copied: dataset/DIV/X2/0896x2.png -> dataset/DIV/final/high/0896.png
# Copied: dataset/DIV/X2/0849x2.png -> dataset/DIV/final/high/0849.png
# Image processing completed.

# %%
import os
from PIL import Image
from collections import Counter

# Paths to your directories
low_res_src = "dataset/DIV/DIV2K_valid_LR_x8"
high_res_src = "dataset/DIV/X2"

# Helper function to count resolutions in a directory
def count_resolutions(directory):
    resolution_counter = Counter()
    total_images = 0

    for file_name in os.listdir(directory):
        file_path = os.path.join(directory, file_name)

        if not os.path.isfile(file_path):
            continue

        try:
            with Image.open(file_path) as img:
                resolution_counter[img.size] += 1
                total_images += 1
        except Exception as e:
            print(f"Error processing file {file_path}: {e}")

    return resolution_counter, total_images

# Analyze low-res and high-res directories
print("Analyzing resolutions in low-res directory...")
low_res_counts, low_res_total = count_resolutions(low_res_src)

print("Analyzing resolutions in high-res directory...")
high_res_counts, high_res_total = count_resolutions(high_res_src)

# Print summary for low-res images
print("\nLow-Resolution Images:")
print(f"Total Images: {low_res_total}")
for resolution, count in low_res_counts.items():
    print(f"{resolution}: {count} images")

# Print summary for high-res images
print("\nHigh-Resolution Images:")
print(f"Total Images: {high_res_total}")
for resolution, count in high_res_counts.items():
    print(f"{resolution}: {count} images")
# Out:
# Analyzing resolutions in low-res directory...
# Analyzing resolutions in high-res directory...
#
# Low-Resolution Images:
# Total Images: 100
# (255, 169): 53 images
# (255, 234): 1 images
# (255, 171): 3 images
# (255, 192): 13 images
# (255, 160): 3 images
# (169, 255): 7 images
# (255, 141): 1 images
# (255, 133): 1 images
# (255, 144): 3 images
# (255, 217): 1 images
# (255, 102): 1 images
# (255, 157): 1 images
# (187, 255): 1 images
# (255, 193): 1 images
# (202, 255): 1 images
# (255, 255): 1 images
# (255, 183): 1 images
# (208, 255): 1 images
# (255, 199): 1 images
# (255, 172): 1 images
# (255, 168): 1 images
# (255, 196): 1 images
# (255, 177): 1 images
# (255, 150): 1 images
#
# High-Resolution Images:
# Total Images: 100
# (1020, 678): 53 images
# (1020, 870): 1 images
# (1020, 768): 13 images
# (834, 1020): 1 images
# (1020, 774): 1 images
# (678, 1020): 7 images
# (810, 1020): 1 images
# (750, 1020): 1 images
# (1020, 576): 3 images
# (1020, 600): 1 images
# (1020, 642): 3 images
# (1020, 564): 1 images
# (1020, 672): 1 images
# (1020, 732): 1 images
# (1020, 786): 1 images
# (1020, 690): 1 images
# (1020, 1020): 1 images
# (1020, 684): 3 images
# (1020, 708): 1 images
# (1020, 630): 1 images
# (1020, 798): 1 images
# (1020, 408): 1 images
# (1020, 534): 1 images
# (1020, 936): 1 images

# %%
import os
import shutil
import random

# Paths to your final directories
low_res_dest = "dataset/DIV/final/low"
high_res_dest = "dataset/DIV/final/high"

# Paths to new directories for selected images
selected_low_res = "dataset/DIV/selected/low"
selected_high_res = "dataset/DIV/selected/high"

# Ensure new directories exist
os.makedirs(selected_low_res, exist_ok=True)
os.makedirs(selected_high_res, exist_ok=True)

# Helper function to select and copy 20 random images
def select_and_copy_images(src_dir, dest_dir, selected_names):
    for file_name in selected_names:
        src_path = os.path.join(src_dir, file_name)
        dest_path = os.path.join(dest_dir, file_name)

        # Copy the file
        shutil.copy2(src_path, dest_path)

# Get the list of file names in both directories
low_res_files = os.listdir(low_res_dest)
high_res_files = os.listdir(high_res_dest)

# Ensure the file names overlap in both directories
common_files = list(set(low_res_files) & set(high_res_files))

if len(common_files) < 20:
    print(f"Not enough common files to select 20 images. Found only {len(common_files)}.")
else:
    # Randomly select 20 common file names
    selected_files = random.sample(common_files, 20)

    # Copy the selected files to the new directories
    select_and_copy_images(low_res_dest, selected_low_res, selected_files)
    select_and_copy_images(high_res_dest, selected_high_res, selected_files)

    print(f"Successfully selected and copied 20 images to \"{selected_low_res}\" and \"{selected_high_res}\".")
# Out:
# Successfully selected and copied 20 images to "dataset/DIV/selected/low" and "dataset/DIV/selected/high".
